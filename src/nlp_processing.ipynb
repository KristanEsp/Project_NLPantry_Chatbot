# %%
import string

# %%
text = "I want a recipe with chicken"
text
# Out:
# 'I want a recipe with chicken'

# %% [markdown]
# # Text pre-processing

# %%
#1.) Lower case the text
text_lower = text.lower()
#2.) remove punctuations
punctuations = string.punctuation
punctuations
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
