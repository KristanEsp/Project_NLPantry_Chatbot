# %%
import import_ipynb
import pandas as pd
import numpy as np
import re
import nltk
nltk.download('punkt_tab')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\krist\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
from nlp_processing import text_preprocessing, nlp_processing, load_ingredients_list, tag_ingredients, identify_ingredients

# %%
#Ingredients Collection Stage
def choose_ingredient_stage(ingredient_list):
    status = "ongoing"
    while status != "done":
        #Get user response
        response = input("Choose your ingredients:")
        #Apply text cleaning to response
        response = text_preprocessing(response)
        response = nlp_processing(response)
        #Detect ingredients from text
        ingredients_list = load_ingredients_list()
        matcher, nlp = tag_ingredients(ingredients_list)
        ingredient = ""
        ingredient = identify_ingredients(matcher, nlp)
        
        #Check if any valid ingredients were added
        if ingredient is not None:
            #Add the ingredient to the ingredient list
            ingredient_list.append(ingredient)
            print(ingredient_list)
        else:
            print("Ingredient was not recognized. Please try again")

# %%
#Choosing Recipe Stage

# %%
#Print Chosen Recipe

# %%
#Dialogue Policy
class DialoguePolicy:
    def __init__(self):
        self.ingredients_list = []
        self.recipe_list = []

# %%
#main
dialogue = DialoguePolicy()
#4 stages: ingredients collection, recipe choosing, recipe output and quit
current_stage = "ingredients_collection"
while current_stage != "quit":
    if current_stage == "ingredients_collection":
        choose_ingredient_stage(dialogue.ingredients_list)
# Out:
# Choose your ingredients: i want nuts
# ['mixed nut']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 7
#       5 while current_stage != "quit":
#       6     if current_stage == "ingredients_collection":
# ----> 7         choose_ingredient_stage(dialogue.ingredients_list)
#
# Cell In[35], line 6, in choose_ingredient_stage(ingredient_list)
#       3 status = "ongoing"
#       4 while status != "done":
#       5     #Get user response
# ----> 6     response = input("Choose your ingredients:")
#       7     #Apply text cleaning to response
#       8     response = text_preprocessing(response)
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# ...
